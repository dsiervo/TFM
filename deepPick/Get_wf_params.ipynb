# %%
from obspy import read
from obspy.core import UTCDateTime


st = read("2016-09-14-0300-00M.COL___4")
st.plot()

# %%
tr = st[0]
tr_array = tr.data
print tr_array
# Out:
# [1533 1541 1564 ..., 1560 1558 1561]

# %%
tr.stats
# Out:
#          network: CM
#          station: DBB
#         location: 20
#          channel: EHZ
#        starttime: 2016-09-14T02:59:55.698393Z
#          endtime: 2016-09-14T03:14:02.028393Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 84634
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({u'record_length': 512, u'encoding': u'STEIM2', 'filesize': 570880, u'dataquality': u'D', u'number_of_records': 145, u'byteorder': u'>'})
