# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import warnings
from sklearn.model_selection import cross_val_score, cross_validate
from time import time
from joblib import dump, load

warnings.filterwarnings('ignore')

path = "/home/daniel/Data/arrays/X.txt"
X = np.loadtxt(path)
print(X.shape)
# Out:
# (17040, 66)

# %%
# separando datos en datos de entrenamiento y datos de testeo (0.25)
X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1], random_state=0)

# %%
def train_ml_model(X, y, model):
    """Entrena el modelo de las estrategias de ML."""

    model.fit(X,y)

    return model

def test_ml_model(X, y, model):
    """Predice utilizando el modelo model sobre los datos de testeo test.
    :param model: Modelo de machine learning previamente entrenado
    :type model: Modelo de machine learning de sklearn o xgboost
    :param y: Datos de testeo
    :type y: 1D numpy array
    """
    # prediciendo con el modelo
    pred = model.predict(X)
    
    print("\nprecision: %s"%precision_score(y, pred)), "cuantas que dijo P realmente lo eran"
    print("recall: %s"%recall_score(y, pred)), "Qué porcentaje de todas las P acertó"
    print("accuracy: %s"%accuracy_score(y, pred))
    print("f1_score: %s"%f1_score(y, pred))

    return pred

# %%
clf1 = RandomForestClassifier(n_estimators=80, max_features="sqrt", max_depth=29, n_jobs=-1)
clf2 = DecisionTreeClassifier(max_depth=15)
clf3 = XGBClassifier(n_estimators=4700, max_depth=10, learning_rate=0.6) #
clf5 = LogisticRegression(C=2)
clf7 = KNeighborsClassifier(n_neighbors=3, n_jobs=-1)
clf8 = MLPClassifier(hidden_layer_sizes=(18,))

classifiers = [clf2, clf1, clf5, clf7, clf8, clf3]

# %%
clfs = classifiers
for clf in clfs:
    model_name = str(clf).split("(")[0]
    print("\n",model_name)
    t0=time()
    train_ml_model(X_train, y_train, clf)
    dump(clf, model_name+"_RUS.joblib")
    print("Tiempo de entrenamiento:", round(time()-t0, 2))
    t1=time()
    y_pred = test_ml_model(X_test, y_test, clf)
    print("Tiempo de testeo:", round(time()-t1, 2))
# Out:
#  DecisionTreeClassifier
# Tiempo de entrenamiento: 1.43
#
# precision: 0.9555116164112704
# recall: 0.9351717464925012
# accuracy: 0.9474178403755869
# f1_score: 0.9452322738386307
# Tiempo de testeo: 0.01
#
#  RandomForestClassifier
# Tiempo de entrenamiento: 0.83
#
# precision: 0.9819458375125376
# recall: 0.9472665699080793
# accuracy: 0.965962441314554
# f1_score: 0.9642945087416892
# Tiempo de testeo: 0.13
#
#  LogisticRegression
# Tiempo de entrenamiento: 0.46
#
# precision: 0.9841112214498511
# recall: 0.9588776003870344
# accuracy: 0.9725352112676057
# f1_score: 0.9713305562362167
# Tiempo de testeo: 0.02
#
#  KNeighborsClassifier
# Tiempo de entrenamiento: 0.06
#
# precision: 0.982447083118224
# recall: 0.9206579583938075
# accuracy: 0.9535211267605633
# f1_score: 0.9505494505494505
# Tiempo de testeo: 2.03
#
#  MLPClassifier
# Tiempo de entrenamiento: 1.6
#
# precision: 0.9831889964340296
# recall: 0.9337203676826318
# accuracy: 0.960093896713615
# f1_score: 0.9578163771712159
# Tiempo de testeo: 0.01
#
#  XGBClassifier
# Tiempo de entrenamiento: 84.44
#
# precision: 0.9870324189526185
# recall: 0.957426221577165
# accuracy: 0.9732394366197183
# f1_score: 0.9720039292730844
# Tiempo de testeo: 0.35

# %% [markdown]
# # Cross validation for feature extraction

# %% [markdown]
# ## Geometry of filterbank --> 512cf

# %%
path1 = "/home/daniel/Data/arrays_256/X.txt"
path2 = "/home/daniel/Data/arrays_256cf/X.txt"
path3 = "/home/daniel/Data/arrays_512/X.txt"
path4 = "/home/daniel/Data/arrays_512cf/X.txt"
path5 = "/home/daniel/Data/arrays/X.txt"
paths = [path1, path2, path3, path4, path5]
for path in paths:
    X = np.loadtxt(path)
    print(path.split("/")[4],X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1],random_state=0)
    scores = cross_val_score(clf3, X_train, y_train, cv=5, scoring='f1', n_jobs=-1)
    print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# arrays_256 (35264, 66)
# Process ForkPoolWorker-6391:
# Process ForkPoolWorker-6374:
# Process ForkPoolWorker-6382:
# Process ForkPoolWorker-6385:
# Process ForkPoolWorker-6388:
# Process ForkPoolWorker-6400:
# Process ForkPoolWorker-6376:
# Process ForkPoolWorker-6390:
# Process ForkPoolWorker-6375:
# Process ForkPoolWorker-6399:
# Process ForkPoolWorker-6386:
# Process ForkPoolWorker-6377:
# Process ForkPoolWorker-6392:
# Process ForkPoolWorker-6383:
# Process ForkPoolWorker-6398:
# Traceback (most recent call last):
# Process ForkPoolWorker-6387:
# Process ForkPoolWorker-6397:
# Process ForkPoolWorker-6396:
# Process ForkPoolWorker-6384:
# Process ForkPoolWorker-6394:
# Process ForkPoolWorker-6395:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-6389:
# Traceback (most recent call last):
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-6393:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 362, in get
#     return recv()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# Process ForkPoolWorker-6379:
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Process ForkPoolWorker-6381:
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-6378:
# KeyboardInterrupt
# Process ForkPoolWorker-6380:
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# Traceback (most recent call last):
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#
# ~/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     663     def get(self, timeout=None):
# --> 664         self.wait(timeout)
#     665         if not self.ready():
#
# ~/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     660     def wait(self, timeout=None):
# --> 661         self._event.wait(timeout)
#     662
#
# ~/anaconda2/envs/python3/lib/python3.6/threading.py in wait(self, timeout)
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#
# ~/anaconda2/envs/python3/lib/python3.6/threading.py in wait(self, timeout)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-74efde2237c4> in <module>
#       9     print(path.split("/")[4],X.shape)
#      10     X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1],random_state=0)
# ---> 11     scores = cross_val_score(clf3, X_train, y_train, cv=5, scoring='f1', n_jobs=-1)
#      12     print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     204             fit_params, return_train_score=return_train_score,
#     205             return_times=True)
# --> 206         for train, test in cv.split(X, y, groups))
#     207
#     208     if return_train_score:
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     719                     # scheduling.
#     720                     ensure_ready = self._managed_backend
# --> 721                     backend.abort_everything(ensure_ready=ensure_ready)
#     722
#     723                 if not isinstance(exception, TransportableException):
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in abort_everything(self, ensure_ready)
#     143     def abort_everything(self, ensure_ready=True):
#     144         """Shutdown the pool and restart a new one with the same parameters"""
# --> 145         self.terminate()
#     146         if ensure_ready:
#     147             self.configure(n_jobs=self.parallel.n_jobs, parallel=self.parallel,
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in terminate(self)
#     321     def terminate(self):
#     322         """Shutdown the process or thread pool"""
# --> 323         super(MultiprocessingBackend, self).terminate()
#     324         if self.JOBLIB_SPAWNED_PROCESS in os.environ:
#     325             del os.environ[self.JOBLIB_SPAWNED_PROCESS]
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in terminate(self)
#     134         if self._pool is not None:
#     135             self._pool.close()
# --> 136             self._pool.terminate()  # terminate does a join()
#     137             self._pool = None
#     138
#
# ~/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py in terminate(self)
#     604         for i in range(n_retries):
#     605             try:
# --> 606                 super(MemmapingPool, self).terminate()
#     607                 break
#     608             except OSError as e:
#
# ~/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py in terminate(self)
#     565         self._state = TERMINATE
#     566         self._worker_handler._state = TERMINATE
# --> 567         self._terminate()
#     568
#     569     def join(self):
#
# ~/anaconda2/envs/python3/lib/python3.6/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     184                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     185                           self._callback, self._args, self._kwargs)
# --> 186                 res = self._callback(*self._args, **self._kwargs)
#     187             self._weakref = self._callback = self._args = \
#     188                             self._kwargs = self._key = None
#
# ~/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, worker_handler, task_handler, result_handler, cache)
#     595
#     596         util.debug('helping task handler/workers to finish')
# --> 597         cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     598
#     599         assert result_handler.is_alive() or len(cache) == 0
#
# ~/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py in _help_stuff_finish(inqueue, task_handler, size)
#     580         # task_handler may be blocked trying to put items on inqueue
#     581         util.debug('removing tasks from inqueue until task handler finished')
# --> 582         inqueue._rlock.acquire()
#     583         while task_handler.is_alive() and inqueue._reader.poll():
#     584             inqueue._reader.recv()
#
# KeyboardInterrupt:
# Process ForkPoolWorker-6371:
# Process ForkPoolWorker-6370:
# Process ForkPoolWorker-6369:
# Process ForkPoolWorker-6372:
# Process ForkPoolWorker-6373:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# KeyboardInterrupt
#   File "/home/daniel/anaconda2/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# ## Noise ratio --> 512cf 50-50

# %%
path1 = "/home/daniel/Data/arrays/X.txt"
path2 = "/home/daniel/Data/arrays_512_0.5/X.txt"
paths = [path1, path2]
for path in paths:
    X = np.loadtxt(path)
    print(path.split("/")[4],X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1],random_state=0)
    scores = cross_val_score(clf3, X_train, y_train, cv=5, scoring='f1', n_jobs=-1)
    print("Accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
# Out:
# arrays (17040, 66)
# Accuracy: 0.974 (+/- 0.006)
# arrays_512_0.5 (17040, 66)
# Accuracy: 0.964 (+/- 0.007)

# %% [markdown]
# ## Preemphasis --> True, 512cf

# %%
path1 = "/home/daniel/Data/arrays/X_CMN.txt"
path2 = "/home/daniel/Data/arrays_512_noPre/X_CMN.txt"
path3 = "/home/daniel/Data/arrays_512_noPre/X.txt"
paths = [path1, path2, path3]
for path in paths:
    X = np.loadtxt(path)
    print(path.split("/")[4],X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1],random_state=0)
    scores = cross_val_score(clf3, X_train, y_train, cv=5, scoring='f1', n_jobs=-1)
    print("Accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
# Out:
# arrays (17040, 66)
# Accuracy: 0.95 (+/- 0.01)
# arrays_512_noPre (17040, 66)
# Accuracy: 0.97 (+/- 0.00)
# arrays_512_noPre (17040, 66)
# Accuracy: 0.97 (+/- 0.00)

# %% [markdown]
# ## CMN --> True, 512cf/X_CMN

# %%
path1 = "/home/daniel/Data/arrays_512/X_CMN.txt"
path2 = "/home/daniel/Data/arrays_512cf_nor/X_CMN.txt"
path3 = "/home/daniel/Data/arrays_512cf_nor/X_CMN.txt"
path5 = "/home/daniel/Data/arrays/X_CMN.txt"
path5 = "/home/daniel/Data/arrays/X.txt"
paths = [path2, path3, path5]
for path in paths:
    X = np.loadtxt(path)
    print(path.split("/")[-2:], X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1],random_state=0)
    scores = cross_val_score(clf3, X_train, y_train, cv=5, scoring='f1', n_jobs=-1)
    print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# %% [markdown]
# ## cepfilter True and energy True

# %%
path1 = "/home/daniel/Data/arrays_512cf_noEn/X_CMN.txt"
path2 = "/home/daniel/Data/arrays_512cf_noCepf/X_CMN.txt"
path3 = "/home/daniel/Data/arrays_512cf_noEn/X.txt"
path4 = "/home/daniel/Data/arrays_512cf_noCepf/X.txt"
paths = [path1, path2, path3, path4]
for path in paths:
    X = np.loadtxt(path)
    print(path.split("/")[4:],X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1],random_state=0)
    scores = cross_val_score(clf3, X_train, y_train, cv=5, scoring='f1', n_jobs=-1)
    print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# %% [markdown]
# # Classifier

# %%
scoring = {'recall' : 'recall', 
           'precision' : 'precision',
           'f1_score' : 'f1'}
score_keys = ['test_precision', 'test_recall', 'test_f1_score']

X = np.loadtxt("/home/daniel/Data/arrays/X.txt")
X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1],random_state=0)
for clf in classifiers:
    print("\n",str(clf).split("(")[0])
    t0=time()
    scores = cross_validate(clf, X_train, y_train, cv=5, scoring=scoring, n_jobs=-1)
    for score in score_keys:
        print("%s: %0.3f (+/- %0.3f)"%(score,scores[score].mean(), scores[score].std() * 2))
    print("Ex. time: %0.2f s (+/- %0.2f)"%(scores["fit_time"].mean(), scores["fit_time"].std() * 2))
# Out:
#  DecisionTreeClassifier
# test_precision: 0.950 (+/- 0.015)
# test_recall: 0.935 (+/- 0.013)
# test_f1_score: 0.942 (+/- 0.012)
# Ex. time: 1.14 s (+/- 0.09)
#
#  RandomForestClassifier
# test_precision: 0.980 (+/- 0.005)
# test_recall: 0.947 (+/- 0.010)
# test_f1_score: 0.963 (+/- 0.007)
# Ex. time: 1.81 s (+/- 0.04)
#
#  LogisticRegression
# test_precision: 0.987 (+/- 0.009)
# test_recall: 0.963 (+/- 0.008)
# test_f1_score: 0.975 (+/- 0.003)
# Ex. time: 0.73 s (+/- 0.03)
#
#  KNeighborsClassifier
# test_precision: 0.984 (+/- 0.005)
# test_recall: 0.920 (+/- 0.011)
# test_f1_score: 0.951 (+/- 0.004)
# Ex. time: 0.16 s (+/- 0.08)
#
#  MLPClassifier
# test_precision: 0.961 (+/- 0.071)
# test_recall: 0.951 (+/- 0.016)
# test_f1_score: 0.955 (+/- 0.031)
# Ex. time: 244.65 s (+/- 41.01)
#
#  XGBClassifier
# test_precision: 0.987 (+/- 0.005)
# test_recall: 0.961 (+/- 0.009)
# test_f1_score: 0.974 (+/- 0.006)
# Ex. time: 71.86 s (+/- 0.99)

# %%
scoring = {'recall' : 'recall', 
           'precision' : 'precision',
           'f1_score' : 'f1'}
scores = cross_validate(clf1, X_train, y_train, cv=5, scoring=scoring, n_jobs=-1)

#print("precision: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

# %%
print(scores.keys())
scores["fit_time"]

#score_keys = ['test_precision', 'test_recall', 'test_f1_score', "fit_time"]
# Out:
# dict_keys(['fit_time', 'score_time', 'test_recall', 'train_recall', 'test_precision', 'train_precision', 'test_f1_score', 'train_f1_score'])
# array([1.2998755 , 2.05401444, 2.0413537 , 1.96790099, 1.93373728])

# %% [markdown]
# ## Generalization test

# %%
ls

# %%
import glob
path = "/home/daniel/Data/arrays_512_PTB/X.txt"
X = np.loadtxt(path)
X_train, X_test, y_train, y_test = train_test_split(X[:,:-1],X[:,-1],random_state=0)
for model in glob.glob("*.joblib"):
    print("\n",model)
    clf = load(model)
    print(X_test.shape)
    y_pred = test_ml_model(X_test,y_test, clf)
# Out:
#  LogisticRegression_RUS.joblib
# (5354, 65)
#
# precision: 0.4925289503175196
# recall: 1.0
# f1_score: 0.6599924915529971
#
#  MLPClassifier_RUS.joblib
# (5354, 65)
#
# precision: 0.4925289503175196
# recall: 1.0
# f1_score: 0.6599924915529971
#
#  KNeighborsClassifier_RUS.joblib
# (5354, 65)
#
# precision: 0.0
# recall: 0.0
# f1_score: 0.0
#
#  RandomForestClassifier_RUS.joblib
# (5354, 65)
#
# precision: 0.49233931240657697
# recall: 0.9992415623814941
# f1_score: 0.6596570284140694
#
#  DecisionTreeClassifier_RUS.joblib
# (5354, 65)
#
# precision: 1.0
# recall: 0.0003792188092529389
# f1_score: 0.000758150113722517
#
#  XGBClassifier_RUS.joblib
# (5354, 65)
#
# precision: 1.0
# recall: 0.0015168752370117557
# f1_score: 0.0030291556228701244
